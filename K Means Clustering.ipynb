# %% [markdown]
# In this exercise, we shall see how the data sets are grouped using K-Means Clustering.

# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("C:/Users/Bharath/Desktop/ML/L00144389/Data/1.csv")
data.head()
# Out:
#    Sr.No.  data1  data2
# 0     0.0   1502   2215
# 1     1.0   1667   2072
# 2     2.0   1611   1957
# 3     3.0   1601   1939
# 4     4.0   1643   1965

# %% [markdown]
# Let's assign data1 as d1 and data2 as d2 and plot the data points using scatter function

# %%
d1 = data['data1'].values
d2 = data['data2'].values
X = np.array(list(zip(d1, d2)))
plt.scatter(d1, d2)

# %% [markdown]
# Now we shall import float from numpy and define the plotKClusters

# %%
from numpy import float

def plotKClusters(value,title):
    plt.scatter(d1, d2, c=value.labels_.astype(float))
    plt.title(title)
    plt.show()

# %% [markdown]
# Let's import Kmeans from sklearn.cluster and cluster the data sets with the value of K

# %%
from sklearn.cluster import KMeans

# %%
c2 = KMeans(n_clusters=2)
c2 = cluster2.fit(X)
plotKClusters(c2,'k = 2')

# %%
c3 = KMeans(n_clusters=3)
c3 = c3.fit(X)
plotKClusters(c3,'k = 3')

# %%
c4 = KMeans(n_clusters=4)
c4 = c4.fit(X)
plotKClusters(c4,'k = 4')

# %%
c5 = KMeans(n_clusters=5)
c5 = c5.fit(X)
plotKClusters(c5,'k = 5')

# %%
c6 = KMeans(n_clusters=6)
c6 = c6.fit(X)
plotKClusters(c6,'k = 6')

# %% [markdown]
# Thus by using K-Means Clustering we were able to group the data sets with respect to K values
